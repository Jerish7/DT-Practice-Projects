# %% [markdown]
# # Dataset Description

# %% [markdown]
# The dataset briefs about the data of employees working in a particular company. The columns describe the details of the employees and they are as follows:
#
# 1.Emp ID
#
# 2.Name Prefix
#
# 3.First Name
#
# 4.Middle Initial
#
# 5.Last Name
#
# 6.Gender
#
# 7.Email
#
# 8.Father's Name
#
# 9.Mother's Name
#
# 10.Mother's Maiden Name
#
# 11.Date of Birth
#
# 12.Time of Birth
#
# 13.Age in Yrs.
#
# 14.Weight in Kgs.
#
# 15.Date of Joining
#
# 16.Quarter of Joining
#
# 17.Half of Joining
#
# 18.Year of Joining
#
# 19.Month of Joining
#
# 20.Month Name of Joining
#
# 21.Short Month - Short form of month name
#
# 22.Day of Joining
#
# 23.DOW of Joining - Day of Week of Joining
#
# 24.Short DOW of Joining
#
# 25.Age in Company(Years) - No.of.years working in the company
#
# 26.Salary
#
# 27.Last % Hike
#
# 28.SSN - Social Security Number
#
# 29.Phone No.
#
# 30.Place Name
#
# 31.County
#
# 32.City
#
# 33.State
#
# 34.Zip
#
# 35.Region
#
# 36.User Name
#
# 37.Password
#
# There are 1000 rows and 37 columns in this dataset. We need to predict the salary of the employee from the given datas and as the data is continuous, we should approach the problem by using regression analysis

# %%
#Importing warning library to avoid any warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
import pandas as pd
df=pd.read_csv('D:/Python file/Project Datasets/1000 Records.csv')  #Path location of the dataset
df.head()  #Checking out the top 5 rows of the dataset
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name  ...          SSN       PhoneNo  Place Name  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# ...

# %%
df.shape  #Checking out the dimensions of the data
# Out:
# (1000, 37)

# %% [markdown]
# The dataset has 1000 rows and 37 columns

# %%
df.columns  #Checking out the columns present
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'PhoneNo', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %% [markdown]
# # Data Preparation

# %%
#Checking out the statistical summary of the data
df.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# ...

# %% [markdown]
# Observations:
#
# 1.There are no missing values in the dataset.
#
# 2.There is not much difference between the mean and median so that we can estimate that there are no outliers present. But still, we can check the dataset whether there are outliers or not.

# %%
df.info()   #Checking out the datatypes of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age in Yrs.             1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %% [markdown]
# There are categorical data present in the dataset and we need to encode it into numerical features

# %%
df.isnull().sum()   #Checking if there are any null values are present or not
# Out:
# Emp ID                    0
# Name Prefix               0
# First Name                0
# Middle Initial            0
# Last Name                 0
# Gender                    0
# E Mail                    0
# Father's Name             0
# Mother's Name             0
# Mother's Maiden Name      0
# Date of Birth             0
# Time of Birth             0
# Age in Yrs.               0
# Weight in Kgs.            0
# Date of Joining           0
# Quarter of Joining        0
# Half of Joining           0
# Year of Joining           0
# Month of Joining          0
# Month Name of Joining     0
# Short Month               0
# Day of Joining            0
# DOW of Joining            0
# Short DOW                 0
# Age in Company (Years)    0
# Salary                    0
# Last % Hike               0
# SSN                       0
# PhoneNo                   0
# Place Name                0
# County                    0
# City                      0
# State                     0
# ...

# %% [markdown]
# As we can see, there are no NaN values present in the dataset

# %% [markdown]
# # Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt   #Importing matplotlib and seaborn libraries

# %% [markdown]
# # Univariate Analysis

# %%
#Plotting distplot for checking normal distribution
sns.distplot(df['Age in Yrs.'])
plt.show()

# %%
sns.distplot(df['Salary'])
plt.show()

# %% [markdown]
# We can see that the data is not normally distributed and it is due to high skewness of data

# %% [markdown]
# # Bivariate Analysis

# %%
#Scatter plot
plt.scatter(df['Salary'],df['Zip'])
plt.title('Scatter plot')
plt.xlabel('Salary')
plt.ylabel('Zip')
plt.show()

# %%
plt.scatter(df['Month of Joining'],df['Year of Joining'])
plt.title('Scatter plot')
plt.xlabel('Month of Joining')
plt.ylabel('Year of Joining')
plt.show()

# %%
#Plotting pairplot for checking the visual relationship between the data
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# There is no relationship between the columns present and we can see the data is neither linear or non-linear

# %% [markdown]
# # Multivariate Analysis

# %%
#Checking correlation of the dataset
corr=df.corr()  #corr() function provides the correlation value of each column
corr
# Out:
#                           Emp ID  Age in Yrs.  Weight in Kgs.  \
# Emp ID                  1.000000    -0.028516        0.028175
# Age in Yrs.            -0.028516     1.000000       -0.065656
# Weight in Kgs.          0.028175    -0.065656        1.000000
# Year of Joining         0.039009    -0.676875        0.058794
# Month of Joining        0.000999     0.022617        0.003933
# Day of Joining          0.006178    -0.026387       -0.038591
# Age in Company (Years) -0.039064     0.676408       -0.058846
# Salary                 -0.027248     0.041422        0.061088
# Zip                     0.020033    -0.017266       -0.021019
#
#                         Year of Joining  Month of Joining  Day of Joining  \
# Emp ID                         0.039009          0.000999        0.006178
# Age in Yrs.                   -0.676875          0.022617       -0.026387
# Weight in Kgs.                 0.058794          0.003933       -0.038591
# ...

# %%
#Plotting heatmap to understand the visualization of correlation
plt.figure(figsize=(20,10))
sns.heatmap(corr,linewidth=0.5,linecolor='black',annot=True)
plt.show()

# %% [markdown]
# Observations:
#
# 1.Most of the data has positive correlations and highest positive correlation is between Age in Company(Years) and Age in Yrs with nearly 68%
#
# 2.Year of Joining and Age in Company(Years) has the more negative correlated value of -100% and it is very poor.
#
# 3.The positive correlated columns has high impact with the target variable and the negatively correlated columns will have zero impact or less impact with the target variable.

# %% [markdown]
# # Handling the dataset

# %% [markdown]
# From the above dataset, we can infer that there are many columns that are not even necessary for analysis and we can drop them from the original data and proceed to further analysis

# %%
#Dropping unnecessary columns
df.drop(columns=['Emp ID','First Name','Middle Initial','Last Name','E Mail',"Father's Name",
                 "Mother's Name","Mother's Maiden Name",'Date of Birth','Time of Birth','Date of Joining',
                'Month Name of Joining','DOW of Joining','SSN','Place Name','PhoneNo','Zip',
                'User Name','Password'],inplace=True)

# %%
df.head()  #Checking dataset after dropping columns
# Out:
#   Name Prefix Gender  Age in Yrs.  Weight in Kgs. Quarter of Joining  \
# 0         Ms.      F        45.66              44                 Q4
# 1         Mr.      M        23.76              52                 Q2
# 2        Drs.      F        22.68              42                 Q1
# 3        Mrs.      F        41.70              43                 Q1
# 4        Hon.      F        22.39              58                 Q4
#
#   Half of Joining  Year of Joining  Month of Joining Short Month  \
# 0              H2             2010                12         Dec
# 1              H1             2017                 4         Apr
# 2              H1             2017                 3         Mar
# 3              H1             2003                 2         Feb
# 4              H2             2016                10         Oct
#
#    Day of Joining Short DOW  Age in Company (Years)  Salary Last % Hike  \
# 0              18       Sat                    6.61  119090         17%
# ...

# %% [markdown]
# # Encoding Categorical data

# %% [markdown]
# Many columns have categorical data and we need to encode it to numerical data. This can be done by using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Name Prefix']=le.fit_transform(df['Name Prefix'].astype(str))
df['Gender']=le.fit_transform(df['Gender'].astype(str))
df['Quarter of Joining']=le.fit_transform(df['Quarter of Joining'].astype(str))
df['Half of Joining']=le.fit_transform(df['Half of Joining'].astype(str))
df['Short Month']=le.fit_transform(df['Short Month'].astype(str))
df['Short DOW']=le.fit_transform(df['Short DOW'].astype(str))
df['County']=le.fit_transform(df['County'].astype(str))
df['City']=le.fit_transform(df['City'].astype(str))
df['State']=le.fit_transform(df['State'].astype(str))
df['Region']=le.fit_transform(df['Region'].astype(str))
df['Last % Hike']=le.fit_transform(df['Last % Hike'].astype(str))

# %%
#Checking the datatype of the columns after encoding
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name Prefix             1000 non-null   int32
#  1   Gender                  1000 non-null   int32
#  2   Age in Yrs.             1000 non-null   float64
#  3   Weight in Kgs.          1000 non-null   int64
#  4   Quarter of Joining      1000 non-null   int32
#  5   Half of Joining         1000 non-null   int32
#  6   Year of Joining         1000 non-null   int64
#  7   Month of Joining        1000 non-null   int64
#  8   Short Month             1000 non-null   int32
#  9   Day of Joining          1000 non-null   int64
#  10  Short DOW               1000 non-null   int32
#  11  Age in Company (Years)  1000 non-null   float64
#  12  Salary                  1000 non-null   int64
#  13  Last % Hike             1000 non-null   int32
# ...

# %%
#Checking out the dataset after encoding
df.head()
# Out:
#    Name Prefix  Gender  Age in Yrs.  Weight in Kgs.  Quarter of Joining  \
# 0            5       0        45.66              44                   3
# 1            3       1        23.76              52                   1
# 2            1       0        22.68              42                   0
# 3            4       0        41.70              43                   0
# 4            2       0        22.39              58                   3
#
#    Half of Joining  Year of Joining  Month of Joining  Short Month  \
# 0                1             2010                12            2
# 1                0             2017                 4            0
# 2                0             2017                 3            7
# 3                0             2003                 2            3
# 4                1             2016                10           10
#
#    Day of Joining  Short DOW  Age in Company (Years)  Salary  Last % Hike  \
# ...

# %% [markdown]
# We can see that all the data has been in numerical features format and it is due to the conversion of categorical data into numerical data by using LabelEncoder

# %% [markdown]
# # Checking skewness of the data

# %%
df.skew()
# Out:
# Name Prefix              -0.437561
# Gender                   -0.036060
# Age in Yrs.               0.006173
# Weight in Kgs.            0.657110
# Quarter of Joining        0.045158
# Half of Joining           0.076169
# Year of Joining          -0.958797
# Month of Joining          0.057287
# Short Month               0.015397
# Day of Joining           -0.143305
# Short DOW                 0.069591
# Age in Company (Years)    0.968211
# Salary                    0.034356
# Last % Hike               0.007634
# County                   -0.003393
# City                      0.012028
# State                    -0.003067
# Region                   -0.069554
# dtype: float64

# %% [markdown]
# As there is less skewness in the dataset , we can handle them by removing outliers

# %% [markdown]
# # Checking any outliers

# %%
#Checking outliers using boxplot
df['Age in Company (Years)'].plot.box()

# %%
df['Year of Joining'].plot.box()

# %% [markdown]
# As there are outliers present , we can handle them by using z-score

# %% [markdown]
# # Handling outliers using z-score

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))   #converting all values into absolute value
threshold=3    #setting up a threshold
np.where(z>3)
# Out:
# (array([594, 594, 606, 621, 621, 684, 684, 895, 999, 999], dtype=int64),
#  array([ 6, 11,  6,  6, 11,  6, 11,  6,  6, 11], dtype=int64))

# %%
#Removing outliers
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Name Prefix  Gender  Age in Yrs.  Weight in Kgs.  Quarter of Joining  \
# 0              5       0        45.66              44                   3
# 1              3       1        23.76              52                   1
# 2              1       0        22.68              42                   0
# 3              4       0        41.70              43                   0
# 4              2       0        22.39              58                   3
# ..           ...     ...          ...             ...                 ...
# 994            0       1        28.61              73                   1
# 995            5       0        32.01              59                   0
# 996            3       1        30.48              84                   0
# 997            2       0        59.88              50                   0
# 998            4       0        30.21              48                   0
#
#      Half of Joining  Year of Joining  Month of Joining  Short Month  \
# ...

# %%
df.shape   #Original dataset dimensions
# Out:
# (1000, 18)

# %%
df_new.shape   #New dataset dimensions
# Out:
# (994, 18)

# %% [markdown]
# # Percentage loss of data while removing outliers

# %%
percentage_loss=((6)/1000)*100
print(percentage_loss)
# Out:
# 0.6

# %% [markdown]
# Data less than 1% has been removed after handling outliers, which is good

# %% [markdown]
# # Preparing dataset for model training

# %% [markdown]
# Splitting x and y

# %%
x=df_new.drop('Salary',axis=1)   #Independent variables
y=df_new['Salary']    #Dependent or Target Variable

# %% [markdown]
# # Removing skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')  #Transforming x data

# %% [markdown]
# # Building the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# # Scaling the data using Standard Scaler

# %%
# lets scale the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaledx=sc.fit_transform(x)

# %%
#Importing required metrices and model for the dataset
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

# %%
#Finding the best random state and accuracy
best_rstate=0
accuracy=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(scaledx,y,test_size=.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print('At random state',i,',the model performs well')
        print('Training r2_score is: ',r2_score(y_train,pred_train)*100)
        print('Testing r2_score is: ',r2_score(y_test,pred_test)*100)

# %% [markdown]
# As the data numerics are not in a particular range, we cannot find the perfect random state and r2 score values. Hence, we need to assume a random state and perform the further analysis

# %% [markdown]
# # Regressor Model Building

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(LinearRegression(),x_train,y_train,cv=5).mean()
print('Accuracy: ',r2score*100)
print('Cross Validation score: ',cvscore*100)
print('Difference: ',(r2score-cvscore)*100)
# Out:
# Accuracy:  0.7226983056702996
# Cross Validation score:  -3.861449420920264
# Difference:  4.5841477265905635

# %% [markdown]
# # SGD Regressor

# %%
from sklearn.linear_model import SGDRegressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)
y_pred=SGD.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(SGDRegressor(),x_train,y_train,cv=5).mean()
print('Accuracy: ',r2score*100)
print('Cross Validation score: ',cvscore*100)
print('Difference: ',(r2score-cvscore)*100)
# Out:
# Accuracy:  1.0157097078577149
# Cross Validation score:  -3.655039424915252
# Difference:  4.670749132772967

# %% [markdown]
# # KNN Regression

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,scaledx,y): #Def is used such that we can call it later
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(scaledx,y,random_state=r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print()
    print('max r2 score correponding to',final_r_state,'is',max_r_score)
    return final_r_state

# %%
#Hyperparameter Tuning using GridSearCV for KNN
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(scaledx,y)
gknr.best_params_
# Out:
# {'n_neighbors': 29}

# %%
knr=KNeighborsRegressor(n_neighbors=29)
r_state=maxr2_score(knr,scaledx,y)
# Out:
# max r2 score correponding to 61 is 0.027810401089990333

# %% [markdown]
# Except Linear Regression, all other algorithms are giving bad accuracy and r2_scores.

# %% [markdown]
# # Regularization

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
x_train_b,x_test_b,y_train_b,y_test_b=train_test_split(scaledx,y,random_state=96,test_size=0.20)

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train_b,y_train_b)
ls.score(x_train_b,y_train_b)
pred_ls=ls.predict(x_test_b)

lss=r2_score(y_test_b,pred_ls)
for j in range(2,10):
    lsscore=cross_val_score(ls,scaledx,y,cv=j)
    lsc=lsscore.mean()
    print('At cv: ',j)
    print('Cross validation score is: ',lsc*100)
    print('r2_score is: ',lss*100)
    print('\n')
# Out:
# At cv:  2
# Cross validation score is:  -2.1940099370331034
# r2_score is:  0.06904450445699428
#
#
# At cv:  3
# Cross validation score is:  -1.4513162561055282
# r2_score is:  0.06904450445699428
#
#
# At cv:  4
# Cross validation score is:  -1.8820286578643985
# r2_score is:  0.06904450445699428
#
#
# At cv:  5
# Cross validation score is:  -2.2678743793876377
# r2_score is:  0.06904450445699428
#
#
# At cv:  6
# Cross validation score is:  -1.3719645206402378
# r2_score is:  0.06904450445699428
#
#
# At cv:  7
# Cross validation score is:  -0.8344369942724996
# r2_score is:  0.06904450445699428
#
#
# At cv:  8
# Cross validation score is:  -1.547225641771359
# r2_score is:  0.06904450445699428
#
#
# At cv:  9
# Cross validation score is:  -1.2581906271144183
# r2_score is:  0.06904450445699428

# %% [markdown]
# At cv=7, we are getting the best value out of all

# %% [markdown]
# # Calculating MAE, MSE, RMSE

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Mean Absolute Error: ',mean_absolute_error(y_test_b,pred_ls))
print('Mean Squared Error: ',mean_squared_error(y_test_b,pred_ls))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test_b,pred_ls)))
# Out:
# Mean Absolute Error:  38144.820964924445
# Mean Squared Error:  1941828594.7135043
# Root Mean Squared Error:  44066.18425406839

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test_b,y=pred_ls,color='r')
plt.plot(y_test_b,y_test_b,color='b')
plt.title('Lasso Regression',fontsize=18)
plt.xlabel('Actual Compressive strength',fontsize=14)
plt.ylabel('Predicted Compressive strength',fontsize=14)
plt.show()

# %% [markdown]
# We can see that the data is neither above best fit line or below the line

# %% [markdown]
# From the algorithms above, we can conclude that Linear Regression alone is performing well and other models are having very low cross val score and poor accuracy rate

# %% [markdown]
# # Conclusion

# %% [markdown]
# The given dataset is not up to the mark and more data is required as the metrics values and accuracy is very low and cross val score is negative for most cases. Hence we can conclude that salary cannot be predicted properly with this dataset

# %% [markdown]
# # Serialization

# %%
import joblib
joblib.dump(SGD,'EmployeeProject.pkl')
# Out:
# ['EmployeeProject.pkl']
